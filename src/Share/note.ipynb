# %% [markdown]
# # 金融知识

# %% [markdown]
# ## 除权/除息，前复权/后复权
#
# 公司进行分红、送股等操作，本质上是在改变公司的总资产、净资产和总股本，从而影响了 *每股所包含的权益（即每股净资产）*。
#
# 在 *股权登记日* 的下一个交易日，交易所会对该股票进行 *除权/除息* 处理：修改该股票的 *基准价（即前收盘价）*。
# - **除权**：针对 *股本变动* 的行为，如送股、转增股、配股
# - **除息**：针对 *现金分红* 的行为
#
# 交易所修改后的价格称为 **除权/除息参考价**
# - 除权参考价 = 股权登记日收盘价 / (1 + 每股送股比例)（针对 *股本变动* 的行为）
# - 除息参考价 = 股权登记日收盘价 - 每股现金股利（针对 *现金分红* 的行为）
# - 混合情况
#
# 除权/除息日，交易所会直接将前收盘价修改为调整后的。
# - 从而 K 线图上会出现一个巨大的缺口，无法真实反映股价的涨跌
# - **复权** 就是为了消除这个缺口，让股价变得连续、平滑，分为 **前复权/后复权**
# - 例子：假设一只股票
#   ```
#   第1天：价格是 10元
#   第2天：公司实施 “10送10” 的分红方案。除权日，股价从 10 元调整为 5元
#   第3天：股价从 5 元涨到 5.5元
#   ```
#   - 前复权：三天价格分别为 `10元 * 0.5 = 5元、5元、5.5元`
#   - 后复权：三天价格分别为 `10元 * 0.5 = 10元、10元、11元`

# %% [markdown]
# # 文件映射到内存 `BoostMappingFile.hpp\BoostMappingFile`

# %% [markdown]
# 对于文件非常大（例如几GB）的场景：
# - 传统方式：打开文件，用 read、write 把数据从硬盘读到内存里的一块缓冲区，处理完再写回硬盘。涉及到频繁的 *I/O操作*，速度慢且繁琐。
# - **内存映射方式**：在程序内存里创建一个映射区域，可以直接通过操作内存地址（指针）来读写文件，操作系统在后台自动处理硬盘和内存之间的数据同步。
#   - BoostMappingFile.hpp 使用 Boost 中的 interprocess 模块来实现这个功能。
#   - ***懒加载（Lazy Loading）***：操作系统并非在映射时就把整个文件都加载到物理内存中，而是在真正访问到某部分数据时，才会通过“缺页中断”机制，把那部分数据从硬盘加载进来。
#   - ***内存共享***：多个进程可以映射同一个文件到各自的地址空间，从而实现高效的进程间通信和数据共享。操作系统会保证数据的一致性。

# %% [markdown]
# 包含成员：
# - `std::string _file_name`：存储映射的文件名
# - `boost::interprocess::file_mapping *_file_map`：文件映射对象指针
# - `boost::interprocess::mapped_region *_map_region`：内存映射区域指针
#
# 包含方法
# - 构造函数：`BoostMappingFile()`
# - 获取映射的文件名：`const char* filename()`
# - 映射文件到内存：`bool map(const char *filename, int mode=boost::interprocess::read_write, int mapmode=boost::interprocess::read_write,bool zeroother=true)`
# - 关闭内存映射：`void close()`
# - 同步内存映射到磁盘：`void sync()`
# - 获取内存映射起始地址：`void *addr()`
# - 获取内存映射大小：`size_t size()`
# - 检查映射是否有效：`bool valid() const`

# %% [markdown]
# # 共享内存 `BoostShm.hpp\BoostShm`

# %% [markdown]
# 在物理内存中开辟一块公共区域，不同进程可以把这块公共区域映射到自己的地址空间里。
# - 极致的进程间通信速度：进程 A 要传递信息时，把数据写到自己对应这块公共区域的地址里，进程 B 可以立刻访问。这个过程几乎没有数据复制，速度极快。
#
# 包含成员：
# - `std::string _name`：共享内存对象的名称，用于标识和查找
# - `boost::interprocess::shared_memory_object* _obj`：共享内存对象指针，boost::interprocess 库的共享内存对象类型
# - `boost::interprocess::mapped_region *	_region`：内存映射区域指针，boost::interprocess 库的映射区域类型
#
# 包含方法：
# - **核心属性与构造函数**
#     - 构造函数：`BoostShm()`
# - **共享内存生命周期管理**
#     - 创建共享内存：`bool create(const char* name, std::size_t size)`
#     - 打开已存在的共享内存：`bool open(const char* name)`
#     - 关闭共享内存：`void close()`
# - **数据访问**
#     - 获取共享内存起始地址：`void *addr()`
#     - 获取共享内存大小：`size_t size()`
# - **状态检查**
#     - 检查共享内存是否有效：`bool valid() const`

# %% [markdown]
# # 字符编码转换工具 `charconv.hpp`

# %% [markdown]
# - 编码格式检测类 `EncodingHelper`：通过分析字节序列的特征来判断编码类型为 UTF-8/GBK。包含方法：
#   - 检测字符串是否为GBK编码：`static bool isGBK(unsigned char* data, std::size_t len)`
#   - 计算UTF-8字符的字节数：`static int preNUm(unsigned char byte)`
#   - 检测字符串是否为UTF-8编码：`static bool isUtf8(unsigned char* data, std::size_t len)`
# - `UTF8toChar` 和 `ChartoUTF8`
# - `URLEncode` 和 `URLDecode`

# %% [markdown]
# # 合约代码解析 `CodeHelper.hpp\CodeHelper`

# %% [markdown]
# ## 主力、次主力、前复权、后复权合约代码后缀
# ```cpp
# //主力合约后缀
# static const char* SUFFIX_HOT = ".HOT";
# //次主力合约后缀
# static const char* SUFFIX_2ND = ".2ND";
# //前复权合约代码后缀
# static const char SUFFIX_QFQ = '-';
# //后复权合约代码后缀
# static const char SUFFIX_HFQ = '+';
# ```

# %% [markdown]
# ## 解析后的合约代码信息 `CodeInfo`
# 包含成员：
# - `char _code[MAX_INSTRUMENT_LENGTH]`：合约代码，如"600000"、"IF2112"
# - `char _exchg[MAX_INSTRUMENT_LENGTH]`：交易所代码，如"SSE"、"CFFEX"
# - `char _product[MAX_INSTRUMENT_LENGTH]`：品种代码，如"STK"、"IF"
# - `char _ruletag[MAX_INSTRUMENT_LENGTH]`：规则标签，用于标识特殊的交易规则
# - `char _fullpid[MAX_INSTRUMENT_LENGTH]`：完整品种ID，格式为"交易所.品种"
# - `uint8_t _exright`：是否是复权代码,如SH600000Q: 0-不复权, 1-前复权, 2-后复权

# %% [markdown]
# ## 合约代码解析类 `CodeHelper`
# 包含方法：
# - **代码标准化与解析**
#     - 从标准代码中提取信息：`static CodeInfo extractStdCode(const char* stdCode, IHotMgr *hotMgr)`
#     - 将原始带月份代码转换为标准代码：`static std::string rawMonthCodeToStdCode(const char* code, const char* exchg)`
#     - 获取标准主力合约代码：`static std::string stdCodeToStdHotCode(const char* stdCode)`
#     - 从股票代码中提取交易所和原始代码：`static CodeInfo extractRawCode(const char* code)`
#     - 将品种和月份组合成原始合约代码：`static std::string composeProductMonth(const char* product, uint32_t month)`
# - **代码类型判断与校验**
#     - 判断是否为标准中国期货期权代码：`static bool isStdChnFutOptCode(const char* code)`
#     - 判断是否为标准主力合约代码：`static bool isStdHotCode(const char* stdCode)`
#     - 判断是否为标准次主力合约代码：`static bool isStd2ndHotCode(const char* stdCode)`
#     - 判断是否为标准的品种代码：`static bool isStdProductCode(const char* stdCode)`
#     - 判断是否为标准的现货/股票代码：`static bool isStdSpotCode(const char* stdCode)`
# - **复权代码处理**
#     - 检查是否为前复权代码：`static bool isQFQ(const char* code)`
#     - 检查是否为后复权代码：`static bool isHFQ(const char* code)`
#     - 移除复权后缀：`static std::string removeExrightSuffix(const char* code)`
# - **工具函数**
#     - 获取当前交易年份：`static uint32_t getTradingYear(uint32_t uDate)`
#     - 获取交易月份：`static uint32_t getTradingMonth(uint32_t uDate)`
#     - 获取合约到期年份：`static uint32_t getContractYear(uint32_t month)`
#     - 获取合约到期月份：`static uint32_t getContractMonth(uint32_t month)`

# %% [markdown]
# ## 例子
# `中国金融期货交易所的沪深300股指期货主力合约（前复权）`，经过
# ```cpp
# CodeHelper::extractStdCode("CFFEX.IF.HOT-", hotMgr)
# ```
# 解析后为
# | 成员 | 值 | 解释 |
# |------|-----|------|
# | `_code` | "IF2406" | 合约代码：由于是主力合约 (.HOT) 且 hotMgr 存在，CodeHelper 会通过 hotMgr 查询当前 IF 的主力合约是 IF2406，所以最终 _code 会填充为实际的主力合约代码。 |
# | `_exchg` | "CFFEX" | 交易所代码：中国金融期货交易所。 |
# | `_product` | "IF" | 品种代码：沪深300股指期货。 |
# | `_ruletag` | "HOT" | 规则标签：表示这是一个"主力合约"的请求。这个字段主要用于区分 .HOT、.2ND 等特殊合约请求，即使 _code 最终被替换为实际合约。 |
# | `_fullpid` | "CFFEX.IF" | 完整品种ID：由"交易所代码"和"品种代码"组合而成，唯一标识一个品种。在 WonderTrader 内部，很多地方用 _fullpid 来索引品种相关的信息。 |
# | `_exright` | 1 (或 CodeHelper::EQ_QFQ) | 复权标记：1 表示前复权 (QFQ - QianFuQuan)。这是因为原始代码带有 "-" 后缀。 (CodeHelper::EQ_QFQ 是一个枚举或宏定义，通常值为1)。 |

# %% [markdown]
# # 命令行参数解析 `cppcli.hpp`
# 用于定义、解析和验证命令行参数，并能自动生成帮助文档。
#
# 核心设计是两个类：Option 和 Rule
# - `Option` 类：整个命令行解析器的主入口和管理器。首先创建一个 Option 对象，它会读取并存储原始的命令行参数
# - `Rule` 类：用于定义单个参数的规则。例如，"-i" 是一个参数，它应该有什么样的规则（是不是必需的？它后面跟的值是什么类型？等等）。
# - 基本流程：
#   - 初始化：创建一个 Option 对象，传入 main 函数的 argc 和 argv
#   - 定义规则：链式调用 Option 对象来为需要的每个参数创建并配置 Rule
#   - 解析与获取：调用 opt.parse() 方法进行解析和验证，然后通过 Rule 对象获取输入的值

# %% [markdown]
# ## 例子
# 假设要开发一个名为 dataproc 的工具，它有以下命令行参数：
# - -i 或 --input：必需的输入文件名
# - -o 或 --output：输出文件名，如果用户不提供，则默认为 "default.out"
# - -l 或 --level：处理级别，必需的，且必须是 "high", "medium", "low" 中的一个
# - -t 或 --threads：使用的线程数，必须是1到8之间的整数，默认为4
# - -v 或 --verbose：一个可选的开关，表示是否显示详细日志
# - -h 或 --help：显示帮助信息
#
# ```cpp
# #include "cppcli.hpp"
# #include <iostream>
#
# int main(int argc, char* argv[]) {
#     // 1. 初始化：创建 Option 对象
#     cppcli::Option opt(argc, argv);
#
#     // 2. 定义规则
#     // 定义输入文件参数
#     auto inputRule = opt("-i", "--input", "指定输入文件路径", true); // true 表示这是必需的
#
#     // 定义输出文件参数，并设置默认值
#     auto outputRule = opt("-o", "--output", "指定输出文件路径");
#     outputRule->setDefault("default.out");
#
#     // 定义处理级别参数，并限制其值
#     auto levelRule = opt("-l", "--level", "设置处理级别", true);
#     levelRule->limitOneOf("high", "medium", "low"); // 限制值只能是这三个之一
#
#     // 定义线程数参数，并限制为整数和范围
#     auto threadsRule = opt("-t", "--threads", "设置线程数量");
#     threadsRule->limitInt()->limitNumRange(1, 8)->setDefault(4); // 链式调用，限制为整数，范围1-8，默认4
#
#     // 定义一个开关参数
#     auto verboseRule = opt("-v", "--verbose", "显示详细日志");
#
#     // 将 -h 定义为帮助参数
#     opt("-h", "--help", "显示此帮助信息")->asHelpParam();
#
#     // 3. 解析与获取
#     try {
#         opt.parse(); // 执行解析和验证，如果失败会自动打印错误信息并退出
#     } catch (const std::exception& e) {
#         std::cerr << "解析参数时发生未知错误: " << e.what() << std::endl;
#         return 1;
#     }
#
#     // 解析成功，获取用户输入的值
#     std::string inputFile = inputRule->get<std::string>();
#     std::string outputFile = outputRule->get<std::string>();
#     std::string level = levelRule->get<std::string>();
#     int threads = threadsRule->get<int>();
#     bool verbose = verboseRule->exists(); // 对于开关参数，用 exists() 判断是否存在
#
#     // 打印获取到的值
#     std::cout << "输入文件: " << inputFile << std::endl;
#     std::cout << "输出文件: " << outputFile << std::endl;
#     std::cout << "处理级别: " << level << std::endl;
#     std::cout << "线程数量: " << threads << std::endl;
#     std::cout << "详细日志: " << (verbose ? "是" : "否") << std::endl;
#
#     return 0;
# }
# ```
#
# 运行方式例如：
# - `./dataproc -i mydata.csv -l high`
# - `./dataproc -h`

# %% [markdown]
# # 线程绑定CPU核心 `CpuHelper.hpp\CpuHelper`
# 现代操作系统会自动、动态地将不同的任务线程分配给不同的 CPU 核心。
#
# 在高频交易和低延迟系统这种对时间要求极致苛刻的场景中，操作系统的这种操作可能会导致：
# - 上下文切换开销：操作系统在CPU核心之间移动线程，这个过程（*上下文切换*）本身需要消耗一些时间（微秒级）
# - 缓存失效：当一个线程从核心A被移到核心B时，它在核心A的缓存中的数据就作废了，到了核心B需要重新从主内存中加载数据，这比直接从缓存中读取慢得多
#
# 类 `CpuHelper` 的核心作用就是将一个的线程绑定在某一个特定的CPU核心上运行。包含方法：
# - 获取当前系统有多少个CPU核心：`static uint32_t get_cpu_cores()`
# - 将当前正在执行这个函数的线程，绑定到索引为 i 的CPU核心上。核心索引从0开始
#     ```cpp
#     static bool bind_core(uint32_t i)
#     ```

# %% [markdown]
# # 基于容差的浮点数比较 `decimal.h`
# 计算机内部浮点数是用有限的二进制位存储的，这导致：有很多位的小数在计算机中无法精确表示，即产生误差。
#
# `decimal.h` 的核心是 ***容差比较***：不要求两个浮点数完全相等，只要它们的差值在一个极小的范围，就认为它们是相等的。

# %% [markdown]
# ## 源码
# ```cpp
# const double EPSINON = 1e-6;  // 定义浮点数比较的精度阈值，用于容差比较
#
# /**
#  * @brief 对浮点数进行四舍五入处理
#  * @param v 需要进行四舍五入的浮点数值
#  * @param exp 精度因子（保留整数位），默认为1，例如100表示保留两位小数
#  * @return double 返回四舍五入后的结果
#  *
#  * 该函数通过乘以精度因子、四舍五入、再除以精度因子的方式
#  * 实现指定精度的四舍五入操作。
#  */
# inline double rnd(double v, int exp = 1)
# {
#     return round(v*exp) / exp;  // 先乘以精度因子，四舍五入，再除以精度因子
# }
#
# /**
#  * @brief 判断两个浮点数是否相等（基于容差比较）
#  * @param a 第一个浮点数值
#  * @param b 第二个浮点数值，默认为0.0
#  * @return bool 如果两个数在EPSINON范围内相等则返回true，否则返回false
#  *
#  * 使用EPSINON作为容差，避免浮点数精度误差导致的比较问题。
#  * 函数声明为noexcept，确保异常安全性。
#  */
# inline bool eq(double a, double b = 0.0) noexcept
# {
#     return(fabs(a - b) < EPSINON);  // 计算两数差值的绝对值，与精度阈值比较
# }
#
# /**
#  * @brief 判断第一个浮点数是否大于第二个浮点数（基于容差比较）
#  * @param a 第一个浮点数值
#  * @param b 第二个浮点数值，默认为0.0
#  * @return bool 如果a大于b且差值超过EPSINON则返回true，否则返回false
#  *
#  * 通过比较差值是否大于精度阈值来判断大小关系，
#  * 避免浮点数精度误差的影响。
#  */
# inline bool gt(double a, double b = 0.0) noexcept
# {
#     return a - b > EPSINON;  // 计算a-b的差值，与精度阈值比较
# }
#
# /**
#  * @brief 判断第一个浮点数是否小于第二个浮点数（基于容差比较）
#  * @param b 第一个浮点数值
#  * @param a 第二个浮点数值，默认为0.0
#  * @return bool 如果b小于a且差值超过EPSINON则返回true，否则返回false
#  *
#  * 通过比较差值是否大于精度阈值来判断大小关系，
#  * 注意参数顺序，使用b-a进行比较。
#  */
# inline bool lt(double a, double b = 0.0) noexcept
# {
#     return b - a > EPSINON;  // 计算b-a的差值，与精度阈值比较
# }
#
# /**
#  * @brief 判断第一个浮点数是否大于等于第二个浮点数（基于容差比较）
#  * @param a 第一个浮点数值
#  * @param b 第二个浮点数值，默认为0.0
#  * @return bool 如果a大于b或a等于b则返回true，否则返回false
#  *
#  * 通过组合大于和等于的判断逻辑，实现大于等于的比较。
#  */
# inline bool ge(double a, double b = 0.0) noexcept
# {
#     return gt(a, b) || eq(a, b);  // 大于或等于，使用逻辑或组合两个条件
# }
#
# /**
#  * @brief 判断第一个浮点数是否小于等于第二个浮点数（基于容差比较）
#  * @param a 第一个浮点数值
#  * @param b 第二个浮点数值，默认为0.0
#  * @return bool 如果a小于b或a等于b则返回true，否则返回false
#  *
#  * 通过组合小于和等于的判断逻辑，实现小于等于的比较。
#  */
# inline bool le(double a, double b = 0.0) noexcept
# {
#     return lt(a, b) || eq(a, b);  // 小于或等于，使用逻辑或组合两个条件
# }
#
# /**
#  * @brief 计算浮点数的模运算结果
#  * @param a 被除数
#  * @param b 除数
#  * @return double 返回a除以b的余数部分
#  *
#  * 该函数计算浮点数除法的余数部分，通过减去整数商的方式实现。
#  * 适用于需要获取浮点数除法小数部分的场景。
#  */
# inline double mod(double a, double b)
# {
#     return a / b - round(a / b);  // 计算除法结果减去四舍五入后的整数部分
# }
# ```

# %% [markdown]
# # 跨平台操作动态库接口 `DLLHelper.hpp\DLLHelper`
# Windows 和 Linux 加载和使用动态库的接口是不同的：
# - Windows：LoadLibrary(), GetProcAddress(), FreeLibrary()
# - Linux：dlopen(), dlsym(), dlclose()
#
# `DLLHelper` 的核心是提供了操作动态库的上层接口，使得 Windows 和 Linux 底层操作动态库的差异被封装起来。
# - 加载一个动态库文件：`static DllHandle load_library(const char *filename)`
# - 从已经加载的动态库中，获取一个函数或变量的地址：`static ProcHandle get_symbol(DllHandle handle, const char* name)`
# - 卸载已经加载的动态库，释放资源：`static void free_library(DllHandle handle)`
# - 生成符合当前操作系统命名规范的库文件名：`static std::string wrap_module(const char* name, const char* unixPrefix = "lib")`

# %% [markdown]
# ## 静态库和动态库
# | 特性维度 | 静态库 (Static Library) | 动态库 (Dynamic Library / Shared Library) |
# |---------|----------------------|------------------------------------------|
# | **文件扩展名** | Windows: .lib <br> Linux/Unix: .a (archive) | Windows: .dll (Dynamic-Link Library) <br> Linux/Unix: .so (Shared Object) |
# | **链接过程** | 编译时静态链接 (Static Linking)<br>在生成最终可执行文件的最后一个阶段，链接器 (Linker) 将库中被引用的函数和数据的二进制代码完整地复制并合并到可执行文件中。 | 运行时动态链接 (Dynamic Linking)<br>编译时，链接器只在可执行文件中记录一个符号引用（例如，"我需要kernel32.dll里的CreateFileW函数"）。当程序实际运行时，操作系统的加载器 (Loader) 才会去查找、加载库，并解析这些引用到内存中的实际地址。 |
# | **可执行文件体积** | 大<br>因为所有需要的代码都被打包进来了。如果有10个程序都用了同一个静态库，那么这个库的代码就会在磁盘上存在10份拷贝。 | 小<br>程序本身只包含引用信息，不包含库的实际代码。库文件是独立存在的。 |
# | **内存占用** | 高<br>当多个使用了同一个静态库的程序同时运行时，每个程序都会在自己的内存空间里加载一份完整的库代码副本。 | 低<br>操作系统非常智能，当多个程序需要同一个动态库时，它只会在物理内存中加载一次，然后将这块共享的内存映射到每个程序的虚拟地址空间。这极大地节省了RAM。 |
# | **程序启动速度** | 快<br>因为所有代码都在一个文件里，程序启动时无需再去外部查找和加载库文件，操作系统直接将整个文件加载到内存即可。 | 相对较慢<br>程序启动时，操作系统需要：<br>1. 解析程序的依赖项。<br>2. 在文件系统中查找并加载所需的 .dll 或 .so 文件。<br>3. 进行地址重定位（Relocation）和符号解析。<br>这个过程会带来轻微的启动延迟。 |
# | **运行时性能** | 理论上稍快<br>函数调用是直接的内部跳转，地址在编译时就确定了。 | 理论上稍慢<br>动态库通常使用位置无关代码 (Position-Independent Code, PIC)，这使得库可以被加载到内存的任意地址。这在函数调用时需要一次额外的间接寻址，会带来微乎其微的性能开销，但在现代CPU上几乎可以忽略不计。 |
# | **部署与分发** | 简单、无依赖<br>生成的是一个"绿色"的独立程序。你可以把它直接拷贝到另一台兼容的电脑上运行，无需安装任何依赖。 | 复杂、有依赖<br>分发程序时，必须同时提供其依赖的所有动态库文件，并确保它们被放置在正确的路径下。否则用户会遇到"缺少xxx.dll"的错误。 |
# | **更新与维护** | 困难、繁琐<br>如果库的一个小Bug被修复，所有使用了这个静态库的程序都必须全部重新编译和链接，才能应用这个修复。 | 简单、灵活<br>只需要更新那个独立的 .dll 或 .so 文件即可。所有依赖它的程序在下一次运行时，就会自动加载新版本的库，享受到修复或新功能。 |
# | **版本管理** | 简单<br>版本在编译时就锁定了，程序和其使用的库版本是强绑定的，不会出现版本冲突。 | 复杂 (可能导致 "DLL Hell")<br>如果系统中存在多个版本的同名动态库，或者一个程序依赖的多个动态库又各自依赖于不同版本的另一个库，就可能导致冲突和程序崩溃。这就是臭名昭著的"DLL地狱"问题。 |
# | **灵活性与扩展性** | 差<br>所有功能模块在编译时就已固定，无法在运行时添加或替换功能。 | 极高<br>这是动态库最强大的优点。它允许程序在运行时根据配置或用户操作动态加载功能模块（插件）。几乎所有支持插件的软件（如Photoshop、VSCode、WonderTrader）都基于此机制。 |
# | **适用场景** | 1. 制作无需安装、小巧的命令行工具。<br>2. 对程序启动速度有极端要求的嵌入式系统或高性能计算。<br>3. 不希望暴露库的接口，将其作为程序内部实现的一部分。 | 1. 绝大多数现代应用程序。<br>2. 操作系统API（Windows API就是一系列DLL）。<br>3. 大型软件项目，需要模块化开发与独立更新。<br>4. 需要实现插件化功能的软件。<br>5. 多个程序需要共享的公共组件（如C++运行时库、Qt框架等）。 |

# %% [markdown]
# # 字符串格式化 `fmtlib.h`

# %% [markdown]
# 经常需要将不同类型的数据（如数字、字符串、日期）组合成一个格式化的字符串。传统方法是使用 `sprintf`，例如
# ```cpp
# char buffer[512];
# int stock_code = 600519;
# double price = 1500.5;
# sprintf(buffer, "合约代码: %d, 当前价格: %.2f", stock_code, price);
# ```
# - 类型不安全：如果把 %d（整数）写成了 %s（字符串），编译器通常不会报错
# - 缓冲区溢出风险：sprintf 不会检查 buffer 的大小。如果格式化后的字符串超过了 buffer 的容量，就会发生缓冲区溢出
# - 性能开销：sprintf 在运行时需要解析格式化字符串，这个过程相对较慢。
#
# fmtlib.h 是对开源库 ***fmt*** 的封装：提供高性能、且完全类型安全的字符串格式化方法。包含方法：
# ```cpp
# 	/**
# 	 * @brief 将格式化结果写入指定缓冲区
# 	 * @tparam Args 可变参数模板，支持任意类型的参数
# 	 * @param buffer 目标缓冲区指针
# 	 * @param format 格式化字符串
# 	 * @param args 要格式化的参数列表
# 	 * @return char* 返回格式化后的字符串指针
# 	 *
# 	 * 该函数使用fmt库将格式化结果写入指定的缓冲区，并在末尾添加字符串结束符。
# 	 * 适用于需要将格式化结果写入预分配缓冲区的场景。
# 	 */
# 	template<typename... Args>
# 	inline char* format_to(char* buffer, const char* format, const Args& ...args)
# 	{
# 		char* s = fmt::format_to(buffer, format, args...);  // 调用fmt库进行格式化，写入指定缓冲区
# 		s[0] = '\0';  // 在格式化结果末尾添加字符串结束符
# 		return s;  // 返回格式化后的字符串指针
# 	}
#
# 	/**
# 	 * @brief 使用线程本地缓冲区进行字符串格式化
# 	 * @tparam BUFSIZE 缓冲区大小，默认为512字节
# 	 * @tparam Args 可变参数模板，支持任意类型的参数
# 	 * @param format 格式化字符串
# 	 * @param args 要格式化的参数列表
# 	 * @return const char* 返回格式化后的字符串指针
# 	 *
# 	 * 该函数使用线程本地的静态缓冲区进行字符串格式化，确保线程安全。
# 	 * 缓冲区大小可通过模板参数自定义，适用于临时字符串格式化的场景。
# 	 *
# 	 * 注意：返回的字符串指针指向线程本地缓冲区，在下次调用前有效。
# 	 */
# 	template<int BUFSIZE=512, typename... Args>
# 	inline const char* format(const char* format, const Args& ...args)
# 	{
# 		thread_local static char buffer[BUFSIZE];  // 线程本地静态缓冲区，确保线程安全
# 		char* s = fmt::format_to(buffer, format, args...);  // 调用fmt库进行格式化，写入线程本地缓冲区
# 		s[0] = '\0';  // 在格式化结果末尾添加字符串结束符
# 		return buffer;  // 返回缓冲区指针
# 	}
# ```

# %% [markdown]
# # INI格式配置文件管理器 `IniHelper.hpp\IniHelper`

# %% [markdown]
# ## INI 配置文件格式
# ***INI文件（Initialization File）*** 是一种经典且广泛使用的配置文件格式：
# - **节**：被包裹在方括号 [ ] 中，单独占一行
# - **键值对**：一个键和一个值的组合，通过等号 = 连接，构成最基本的配置单元
#   - INI文件本身是纯文本格式，所以所有的值本质上都是字符串。程序在读取时，需要自行将字符串转换成相应的类型
# - 注释；使用分号 ; 或井号 # 开头的行
#
# 上述只是约定俗称的惯例，INI 文件本身是纯文本格式，具体如何被解析取决于解析器的实现。
#
# | 特性 | INI | JSON | XML |
# |------|-----|------|-----|
# | **可读性** | 极高，对人类最友好 | 较高，但符号较多 | 较高，但标签繁琐 |
# | **简洁性** | 非常简洁 | 相对简洁 | 冗长，标签占比较大 |
# | **数据结构** | 简单 (一层键值对) | 复杂 (支持嵌套、数组) | 非常复杂 (支持嵌套、属性、命名空间) |
# | **数据类型** | 仅字符串 (需程序转换) | 支持字符串、数字、布尔、数组、对象 | 仅字符串 (需程序转换或使用Schema定义) |
# | **标准化** | 无统一的官方标准，实现有差异 | 有严格的ECMA标准 | 有严格的W3C标准 |
# | **注释** | 支持 (通常是 ; 或 #) | 不支持 (标准格式不支持) | 支持 (<!-- -->) |
# | **适用场景** | 简单的应用程序配置、驱动信息 | Web API、复杂配置、数据交换 | 企业级应用、Web服务、文档标记 |
#
# 例子：
# ```ini
# ; =====================================
# ; MediaPlayer v1.2.0 配置文件
# ; 最后修改日期: 2024-09-15
# ; =====================================
#
# # 全局设置
# # 全局设置可以放在文件的最开始
# AutoCheckForUpdates = true
#
# [VideoSettings]
# ; 视频渲染引擎，可以是 "DirectX", "OpenGL", "Vulkan"
# Renderer = DirectX
# ; 默认开启硬件加速
# HardwareAcceleration = true
# ; 视频解码线程数，0表示自动
# DecoderThreads = 0
#
# [AudioSettings]
# ; 默认音量，范围 0-100
# DefaultVolume = 75
# ; 音频输出设备，留空表示使用系统默认
# OutputDevice =
# MuteOnStart = false
#
# [Interface]
# ; 界面语言，支持 "en-US", "zh-CN"
# Language = zh-CN
# ; 界面主题
# Theme = Dark
# ; 记住窗口上次的位置和大小
# RememberWindowPosition = true
#
# [RecentFiles]
# ; 最近打开的文件列表，键可以是任意的，但通常用数字
# File1 = C:\Movies\Inception.mkv
# File2 = D:\Videos\Tutorial.mp4
# ```

# %% [markdown]
# ## 类 `IniHelper`
# 本质上是一个 INI 格式配置文件解析器。包含成员：
# - `boost::property_tree::ptree _root`：属性树根节点，存储所有配置数据
# - `std::string _fname`：当前加载的INI文件名
# - `bool _loaded`：标记是否已成功加载配置文件
#
# 使用流程：
# - 创建一个 IniHelper 的实例。
# - 调用 load() 方法，传入 INI 文件的路径。IniHelper 会自动解析文件内容并加载到内存的属性树中
# - 调用 read... 或 write... 系列函数来获取或修改配置项。
# - 保存文件（如果需要）：可以调用 save() 方法将内存中的更改写回文件
#
# 例子：
# ```cpp
# #include "IniHelper.hpp"
# #include <iostream>
# #include <string>
#
# int main() {
#     // 1. 创建 IniHelper 对象
#     IniHelper config;
#
#     // 2. 加载配置文件
#     config.load("config.ini");
#
#     // 检查文件是否加载成功（虽然即使文件不存在load也不会报错，但这是个好习惯）
#     if (!config.isLoaded()) {
#         std::cerr << "配置文件 config.ini 加载失败!" << std::endl;
#         return 1;
#     }
#
#     // 3. 读取配置项
#     // 读取 [database] 节
#     std::string db_host = config.readString("database", "host", "localhost"); // 第三个参数是默认值
#     int db_port = config.readInt("database", "port", 3306);
#     std::string db_user = config.readString("database", "username", "guest");
#     std::string db_pass = config.readString("database", "password", "");
#
#     // 读取 [strategy_params] 节
#     std::string symbol = config.readString("strategy_params", "symbol", "default.symbol");
#     std::string period = config.readString("strategy_params", "period", "m1");
#     int fast_ma = config.readInt("strategy_params", "fast_ma", 5);
#     int slow_ma = config.readInt("strategy_params", "slow_ma", 10);
#     bool enable_trading = config.readBool("strategy_params", "enable_trading", false);
#
#     // 4. 修改并保存配置（示例）
#     // 假设我们通过程序逻辑将快线参数调整为12
#     config.writeInt("strategy_params", "fast_ma", 12);
#     config.save("config_new.ini"); // 保存到一个新文件
#
#     return 0;
# }
# ```

# %% [markdown]
# # 当前代码动态库路径查询 `ModuleHelper.hpp`
# WonderTrader 是一个插件化的平台
# - 核心功能（如连接CTP的交易接口）都是以独立的动态链接库（Windows上的.dll，Linux上的.so）的形式存在的
# - 这些插件模块，在被主程序加载后，必须首先知道自己这个 .dll 或 .so 文件被存放在哪个文件夹里
#
# ModuleHelper.hpp 提供的函数 `getBinDir()` 的作用是：
# - 获取（可以跨平台）当前正在执行这段代码的模块（.dll 或 .so）所在的目录路径

# %% [markdown]
# # 对象池 `ObjectPool.hpp`

# %% [markdown]
# 当需要频繁地创建和销毁同一种类型的对象时，向操作系统申请和释放内存是一个相对较慢的操作
#
# **对象池**：预先分配一大块内存，并在这块内存上重复利用对象，从而避免了频繁的系统内存调用
#
# 用法：假设有一个经常需要创建和销毁的类 A
# - 创建专门用于管理 A 对象的池子 `ObjectPool<Order> APool;`
#     ```cpp
#     ObjectPool() :_pool(sizeof(T)) {}  // 初始化内存池，块大小为 T 类型的大小
#     ```
# - 获取对象 `A* myA1 = APool.construct();`
#     ```cpp
#     T* construct()
#     {
#         void * mem = _pool.malloc();  // 从内存池中分配内存块（注意这里是 boost::pool<> 类型的 malloc，不需要向操作系统申请内存）
#         if (!mem)  // 检查内存分配是否成功
#             return nullptr;  // 分配失败时返回nullptr
#
#         T* pobj = new(mem) T();  // 使用placement new在指定内存上构造对象
#         return pobj;  // 返回构造好的对象指针
#     }
#     ```
# - 归还对象 `APool.destroy(myA1);`
#     ```cpp
#     void destroy(T* pobj)
#     {
#         pobj->~T();  // 调用对象的析构函数，清理对象资源
#         _pool.free(pobj);  // 将内存归还给内存池（同样这里是 boost::pool<> 类型的 free）
#     }
#     ```
# - 释放池子中未使用的内存块 `APool.release();`
#     ```cpp
#     void release()
#     {
#         _pool.release_memory();  // 释放内存池中未使用的内存块
#     }
#     ```

# %% [markdown]
# ## 源码
# ```cpp
# /**
#  * @class ObjectPool
#  * @brief 对象池模板类
#  * @tparam T 对象类型模板参数
#  *
#  * 该类提供了基于Boost.Pool的高性能对象池功能，
#  * 支持任意类型对象的快速分配和回收。
#  * 通过内存池技术减少内存碎片，提高分配效率。
#  */
# template < typename T>
# class ObjectPool
# {
# 	boost::pool<> _pool;  // Boost内存池对象，管理指定大小的内存块
#
# public:
# 	/**
# 	 * @brief 默认构造函数
# 	 *
# 	 * 初始化对象池，设置内存块大小为模板类型T的大小。
# 	 * 内存池会自动管理内存的分配和回收。
# 	 */
# 	ObjectPool() :_pool(sizeof(T)) {}  // 初始化内存池，块大小为T类型的大小
#
# 	/**
# 	 * @brief 虚析构函数
# 	 *
# 	 * 虚析构函数确保继承类能够正确析构。
# 	 * Boost.Pool会自动管理内存的释放。
# 	 */
# 	virtual ~ObjectPool() {}  // 虚析构函数，支持继承
#
# 	/**
# 	 * @brief 构造并返回一个新对象
# 	 * @return T* 成功时返回对象指针，失败时返回nullptr
# 	 *
# 	 * 该函数从内存池中分配内存，然后使用placement new构造对象。
# 	 * 如果内存分配失败，返回nullptr。
# 	 *
# 	 * 注意：返回的对象需要手动调用destroy函数进行销毁。
# 	 */
# 	T* construct()
# 	{
# 		void * mem = _pool.malloc();  // 从内存池中分配内存块
# 		if (!mem)  // 检查内存分配是否成功
# 			return nullptr;  // 分配失败时返回nullptr
#
# 		T* pobj = new(mem) T();  // 使用placement new在指定内存上构造对象
# 		return pobj;  // 返回构造好的对象指针
# 	}
#
# 	/**
# 	 * @brief 销毁对象并回收内存
# 	 * @param pobj 要销毁的对象指针
# 	 *
# 	 * 该函数先调用对象的析构函数，然后将内存归还给内存池。
# 	 * 使用RAII原则确保资源的正确释放。
# 	 *
# 	 * 注意：该函数会调用对象的析构函数，确保对象正确清理。
# 	 */
# 	void destroy(T* pobj)
# 	{
# 		pobj->~T();  // 调用对象的析构函数，清理对象资源
# 		_pool.free(pobj);  // 将内存归还给内存池，供后续使用
# 	}
#
# 	/**
# 	 * @brief 手动释放未使用的内存
# 	 *
# 	 * 该函数释放内存池中未使用的内存块，减少内存占用。
# 	 * 适用于需要优化内存使用的场景。
# 	 *
# 	 * 注意：释放后，已分配的对象仍然有效，但新分配可能触发新的内存分配。
# 	 */
# 	void release()
# 	{
# 		_pool.release_memory();  // 释放内存池中未使用的内存块
# 	}
# };
# ```

# %% [markdown]
# # 自旋锁 SpinMutex.hpp
# 普通互斥锁的问题：
# - 当普通互斥锁的占用时间比较短（例如几十纳秒），那么 *阻塞* 和 *解除阻塞* 相较而言会非常耗时（线程的上下文切换，需要操作系统内核介入，可能达到几千纳秒）
#
# 自旋锁的设计理念：
# - 提供一个标志位，当这个标志位为真（被占用），一直循环检测是否为假（已经解除占用），所以几乎可以以零延迟获得/解除该标志位
# - 所以只适用于标志位占用时间较短的情况，如果比较长，就会有较长时间的 *CPU空转*
#
# 该文件包含两个类：**自旋锁 `SpinMutex`** 和 **自旋锁包装器 `SpinLock`**
#
# 使用方式：
# - 定义一个自旋锁
#     ```cpp
#     SpinMutex counter_mutex;
#     ```
# - 在需要访问共享资源的多个代码块中，创建各自的自旋锁包装器，并用其包装创建的自旋锁（遵循RAII，即创建加锁，销毁解锁）
#     ```cpp
#     {
#         SpinLock lock(counter_mutex); // 创建时，自动加锁
#     } // 离开作用域时，自动解锁
#     ```

# %% [markdown]
# ## 内存屏障
# 对于单个线程，编译器为了提升执行速度，可能会打乱原子级的代码顺序。当有多个线程时，上述操作可能会导致问题。
#
# 当对某线程中的某原子操作指定下述模式时
# - `std::memory_order_relaxed`：不设置任何屏障，即任由编译器调整底层执行顺序
# - `std::memory_order_release`：向下屏障，上面的任何内存操作不能挪到该操作的下面
# - `std::memory_order_acquire`：向上屏障，下面的任何内存操作不能挪到该操作的上面

# %% [markdown]
# ## 自旋锁 `SpinMutex`
# ```cpp
# /**
#  * @class SpinMutex
#  * @brief 自旋互斥量类
#  *
#  * 该类实现了基于原子操作的自旋互斥量，通过自旋等待实现线程同步。
#  * 适用于锁持有时间很短的场景，避免了传统互斥量的线程阻塞开销。
#  * 使用内存序控制确保正确的内存同步和可见性。
#  */
# class SpinMutex
# {
# private:
# 	std::atomic<bool> flag = { false };  // 原子布尔标志，false表示未锁定，true表示已锁定
#
# public:
# 	/**
# 	 * @brief 获取锁
# 	 *
# 	 * 该函数通过自旋等待获取锁。如果锁已被占用，会持续自旋等待直到获得锁。
# 	 * 使用exchange操作确保原子性，通过内存序控制保证正确的内存同步。
# 	 *
# 	 * 注意：该函数会一直自旋直到获得锁，适用于锁持有时间很短的场景。
# 	 */
# 	void lock()
# 	{
# 		for (;;)  // 无限循环，直到成功获得锁
# 		{
# 			if (!flag.exchange(true, std::memory_order_acquire))  // 尝试将标志设置为true，如果原值为false则成功
# 				break;  // 成功获得锁，跳出循环
#
# 			while (flag.load(std::memory_order_relaxed))  // 等待锁被释放，使用relaxed内存序减少开销
# 			{
# #ifdef _MSC_VER  // Windows平台
# 				_mm_pause();  // 使用Intel SSE指令暂停CPU，优化自旋等待
# #else  // Linux/Unix平台
# 				__builtin_ia32_pause();  // 使用GCC内置函数暂停CPU，优化自旋等待
# #endif
# 			}
# 		}
# 	}
#
# 	/**
# 	 * @brief 释放锁
# 	 *
# 	 * 该函数释放当前持有的锁，允许其他线程获取锁。
# 	 * 使用release内存序确保锁释放操作对其他线程可见。
# 	 */
# 	void unlock()
# 	{
# 		flag.store(false, std::memory_order_release);  // 将标志设置为false，表示锁已释放
# 	}
# };
# ```

# %% [markdown]
# ## 自旋锁包装器 `SpinLock`
# ```cpp
# /**
#  * @class SpinLock
#  * @brief 自旋锁RAII包装器类
#  *
#  * 该类提供了RAII风格的自旋锁管理，在构造时自动获取锁，
#  * 在析构时自动释放锁，确保锁的正确管理。
#  * 禁止拷贝构造和赋值操作，防止意外的锁管理问题。
#  */
# class SpinLock
# {
# public:
# 	/**
# 	 * @brief 构造函数，自动获取锁
# 	 * @param mtx 要管理的自旋互斥量引用
# 	 *
# 	 * 在构造时自动调用mutex的lock函数获取锁。
# 	 * 使用引用确保对同一个互斥量进行操作。
# 	 */
# 	SpinLock(SpinMutex& mtx) :_mutex(mtx) { _mutex.lock(); }  // 构造时自动获取锁
#
# 	/**
# 	 * @brief 删除拷贝构造函数
# 	 *
# 	 * 禁止拷贝构造，防止多个SpinLock对象管理同一个锁，
# 	 * 避免重复加锁或提前释放锁的问题。
# 	 */
# 	SpinLock(const SpinLock&) = delete;  // 删除拷贝构造函数
#
# 	/**
# 	 * @brief 删除赋值操作符
# 	 *
# 	 * 禁止赋值操作，防止多个SpinLock对象管理同一个锁，
# 	 * 确保锁管理的唯一性和安全性。
# 	 */
# 	SpinLock& operator=(const SpinLock&) = delete;  // 删除赋值操作符
#
# 	/**
# 	 * @brief 析构函数，自动释放锁
# 	 *
# 	 * 在析构时自动调用mutex的unlock函数释放锁。
# 	 * 确保即使发生异常，锁也能被正确释放。
# 	 */
# 	~SpinLock() { _mutex.unlock(); }  // 析构时自动释放锁
#
# private:
# 	SpinMutex&	_mutex;  // 自旋互斥量的引用，用于锁的管理
# };
# ```

# %% [markdown]
# # C++标准库部分功能封装 `StdUtils.hpp`

# %% [markdown]
# ## 线程、锁相关封装

# %% [markdown]
# ```cpp
# typedef std::thread StdThread;  // 标准线程类型别名，简化类型名称
# typedef std::shared_ptr<StdThread> StdThreadPtr;  // 标准线程智能指针类型别名
#
# typedef std::recursive_mutex	StdRecurMutex;  // 递归互斥量类型别名，支持同一线程多次加锁
# typedef std::mutex				StdUniqueMutex;  // 普通互斥量类型别名，不支持递归加锁
# typedef std::condition_variable_any	StdCondVariable;  // 任意类型互斥量的条件变量类型别名
# typedef std::unique_lock<StdUniqueMutex>	StdUniqueLock;  // 唯一锁类型别名，RAII风格的锁管理
#
# /**
#  * @class StdLocker
#  * @brief 标准锁RAII包装器模板类
#  * @tparam T 互斥量类型模板参数
#  *
#  * 该类提供了RAII风格的锁管理，在构造时自动加锁，
#  * 在析构时自动解锁，确保锁的正确管理。
#  * 适用于需要手动控制锁生命周期的场景。
#  */
# template<typename T>
# class StdLocker
# {
# public:
# 	/**
# 	 * @brief 构造函数，自动加锁
# 	 * @param mtx 要管理的互斥量引用
# 	 *
# 	 * 在构造时自动调用互斥量的lock函数加锁。
# 	 * 保存互斥量指针，供析构时解锁使用。
# 	 */
# 	StdLocker(T& mtx)
# 	{
# 		mtx.lock();  // 自动加锁
# 		_mtx = &mtx;  // 保存互斥量指针
# 	}
#
# 	/**
# 	 * @brief 析构函数，自动解锁
# 	 *
# 	 * 在析构时自动调用互斥量的unlock函数解锁。
# 	 * 确保即使发生异常，锁也能被正确释放。
# 	 */
# 	~StdLocker(){
# 		_mtx->unlock();  // 自动解锁
# 	}
#
# private:
# 	T* _mtx;  // 互斥量指针，用于析构时解锁
# };
# ```

# %% [markdown]
# ## 文件辅助类 `StdFile`
# 全部是静态方法，包含：
# - **读取文件内容到字符串**
#     ```cpp
#     /**
#      * @brief 读取文件内容到字符串
#      * @param filename 要读取的文件名
#      * @param content 输出参数，存储文件内容的字符串
#      * @return uint64_t 返回读取的字节数
#      *
#      * 该函数以二进制模式打开文件，读取全部内容到指定的字符串中。
#      * 使用fseek和ftell获取文件大小，然后分配内存并读取内容。
#      *
#      * 注意：该函数会覆盖content字符串的原有内容。
#      */
#     static inline uint64_t read_file_content(const char* filename, std::string& content)
#     ```
# - **将字符串内容写入文件**
#     ```cpp
#     /**
#      * @brief 将字符串内容写入文件
#      * @param filename 目标文件名
#      * @param content 要写入的字符串内容
#      *
#      * 该函数以二进制写入模式打开文件，将字符串内容写入文件。
#      * 如果文件已存在，会覆盖原有内容；如果不存在，会创建新文件。
#      */
#     static inline void write_file_content(const char* filename, const std::string& content)
#     ```
# - **将二进制数据写入文件**
#     ```cpp
#     /**
#      * @brief 将二进制数据写入文件
#      * @param filename 目标文件名
#      * @param data 要写入的二进制数据指针
#      * @param length 数据长度（字节数）
#      *
#      * 该函数以二进制写入模式打开文件，将指定长度的二进制数据写入文件。
#      * 适用于写入任意类型的二进制数据，如结构体、数组等。
#      */
#     static inline void write_file_content(const char* filename, const void* data, std::size_t length)
#     ```
# - **检查文件是否存在**
#     ```cpp
#     /**
#      * @brief 检查文件是否存在
#      * @param filename 要检查的文件名
#      * @return bool 文件存在返回true，不存在返回false
#      *
#      * 该函数通过尝试访问文件来检查文件是否存在。
#      * 使用条件编译实现跨平台兼容性：
#      * - Windows平台使用_access函数
#      * - Unix/Linux平台使用access函数
#      */
#     static inline bool exists(const char* filename)
#     ```

# %% [markdown]
# # 字符串工具类 `StrUtil.hpp`
# 全部是静态方法，包含：
# - **字符串清理与修剪**
#   - 修剪字符串两端（原地修改）：`static inline void trim(std::string& str, const char* delims = " \t\r", bool left = true, bool right = true)`
#   - 修剪字符串两端（返回新字符串）：`static inline std::string trim(const char* str, const char* delims = " \t\r", bool left = true, bool right = true)`
#   - 去除字符串中所有空格：`static inline void trimAllSpace(std::string &str)`
# - **字符串查找与分割**
#   - 正向查找首个字符：`static inline std::size_t findFirst(const char* str, char ch)`
#   - 反向查找最后一个字符：`static inline std::size_t findLast(const char* str, char ch)`
#   - 分割字符串（返回新向量）：`static inline StringVector split( const std::string& str, const std::string& delims = "\t\n ", unsigned int maxSplits = 0)`
#   - 分割字符串（存入现有向量）：`static inline void split(const std::string& str, StringVector& ret, const std::string& delims = "\t\n ", unsigned int maxSplits = 0)`
# - **大小写转换 (Case Conversion)**
#   - 转为小写（原地修改）：`static inline void toLowerCase( std::string& str )`
#   - 转为大写（原地修改）：`static inline void toUpperCase( std::string& str )`
#   - 创建小写字符串（返回新字符串）：`static inline std::string makeLowerCase(const char* str)`
#   - 创建大写字符串（返回新字符串）：`static inline std::string makeUpperCase(const char* str)`
# - **模式匹配与比较**
#   - 检查是否以指定模式开头：`static inline bool startsWith(const char* str, const char* pattern, bool ignoreCase = true)`
#   - 检查是否以指定模式结尾：`static inline bool endsWith(const char* str, const char* pattern, bool ignoreCase = true)`
#   - 通配符模式匹配：`static inline bool match(const std::string& str, const std::string& pattern, bool caseSensitive = true)`
# - **路径处理**
#   - 标准化路径：`static inline std::string standardisePath( const std::string &init, bool bIsDir = true)`
#   - 分割完整文件名为路径和基本名称：`static inline void splitFilename(const std::string& qualifiedName,std::string& outBasename, std::string& outPath)`
# - **格式化与工具函数**
#   - 替换子字符串：`static inline void replace(std::string& str, const char* src, const char* des)`
#   - C-Style格式化输出：`static inline std::string printf(const char *pszFormat, ...)`
#   - 获取字符串左边N个字符：`static inline std::string left(const std::string &src,size_t nCount)`
#   - 获取字符串右边N个字符：`static inline std::string right(const std::string &src,size_t nCount)`
#   - 统计字符出现次数：`static inline size_t charCount(const std::string &src,char ch)`
#   - 扩展字符串至指定长度（居中对齐）：`static inline std::string extend(const char* str, uint32_t length)`
#   - 获取空白字符串常量：`static inline const std::string BLANK()`

# %% [markdown]
# # 线程池入口头文件 `threadpool.hpp`

# %% [markdown]
# # 时间工具类 `TimeUtils.hpp\TimeUtils`
# 类 `TimeUtils` 提供了一个高性能、高精度、跨平台的时间管理：
# - Windows 上，通过直接访问一个名为 KUSER_SHARED_DATA 的内核共享内存区域来读取系统时间。这绕过了从用户态到内核态的昂贵切换
# - Linux 上，使用 clock_gettime(CLOCK_REALTIME, ...)，相比于老的 ftime 或 gettimeofday，前者是现代 Linux 上获取高精度时间戳的更好方式

# %% [markdown]
# 包含的方法以及辅助类 `Ticker`、`Time32`：
# - **高精度时间戳获取**
#   - 获取当前毫秒级时间戳: `static inline int64_t getLocalTimeNow(void)`
#   - 获取当前日期 (YYYYMMDD): `static inline uint32_t getCurDate()`
#   - 获取当前时间 (HHMMSS): `static inline uint32_t getCurMin()`
#   - 分别获取当前日期和时间: `static inline void getDateTime(uint32_t &date, uint32_t &time)`
#   - 获取YYYYMMDDhhmmss格式时间戳: `static inline uint64_t getYYYYMMDDhhmmss()`
# - **时间格式化与转换**
#   - 获取格式化的本地时间字符串: `static inline std::string getLocalTime(bool bIncludeMilliSec = true)`
#   - 将毫秒时间戳转换为字符串: `static std::string timeToString(int64_t mytime)`
#   - 根据日期和时间生成毫秒时间戳: `static inline int64_t makeTime(long lDate, long lTimeWithMs, bool isToUTC = false)`
#   - 将日期和时间转换为分钟K线时间戳: `static inline uint64_t timeToMinBar(uint32_t uDate, uint32_t uTime)`
#   - 从分钟K线时间戳提取日期: `static inline uint32_t minBarToDate(uint64_t minTime)`
#   - 从分钟K线时间戳提取时间: `static inline uint32_t minBarToTime(uint64_t minTime)`
# - **日期与时间计算**
#   - 获取N天后的日期: `static uint32_t getNextDate(uint32_t curDate, int days = 1)`
#   - 获取N分钟后的时间: `static uint32_t getNextMinute(int32_t curTime, int32_t mins = 1)`
#   - 获取N月后的月份: `static uint32_t getNextMonth(uint32_t curMonth, int months = 1)`
#   - 获取指定日期的星期: `static inline uint32_t getWeekDay(uint32_t uDate = 0)`
#   - 判断是否为周末: `static inline bool isWeekends(uint32_t uDate)`
# - **工具函数**
#   - 获取时区偏移量（小时）: `static inline int32_t getTZOffset()`
#
# - **内嵌高精度计时器类: Ticker (High-Precision Timer Class: Ticker)**
#   - 构造函数（开始计时）: `Ticker()`
#   - 重置计时器: `void reset()`
#   - 获取经过的秒数: `inline int64_t seconds() const`
#   - 获取经过的毫秒数: `inline int64_t milli_seconds() const`
#   - 获取经过的微秒数: `inline int64_t micro_seconds() const`
#   - 获取经过的纳秒数: `inline int64_t nano_seconds() const`
#
# - **内嵌32位时间辅助类: Time32 (32-bit Time Helper Class: Time32)**
#   - 默认构造函数: `Time32()`
#   - 从time_t和毫秒构造: `Time32(time_t _time, uint32_t msecs = 0)`
#   - 从毫秒级时间戳构造: `Time32(uint64_t _time)`
#   - 从毫秒级时间戳设置时间: `void from_local_time(uint64_t _time)`
#   - 获取日期 (YYYYMMDD): `uint32_t date()`
#   - 获取时间 (HHMMSS): `uint32_t time()`
#   - 获取带毫秒的时间 (HHMMSSmmm): `uint32_t time_ms()`
#   - 格式化为字符串: `const char* fmt(const char* sfmt = "%Y.%m.%d %H:%M:%S", bool hasMilliSec = false) const`

# %% [markdown]
# # 高性能键值对缓存 `WtKVCache.hpp\WtKVCache`
# 实现了一个高效的键值对缓存系统。结合了两种技术：
# - 内存映射文件：将一个磁盘文件直接映射到程序的虚拟内存地址空间
#   - 程序可以像读写一个普通内存数组一样去读写这个文件
#   - 操作系统在后台负责将内存中的更改同步回磁盘，这避免了传统 read/write 系统调用带来的大量开销。
# - 内存哈希索引：内存地址空间以哈希表的形式组织，从而可以以 O(1) 的效率访问数据

# %% [markdown]
# 包含成员：
# - ***`CacheBlockPair _cache`***：缓存块和文件映射对
#   - ***`CacheBlock* _block`***：缓存块指针
#     ```cpp
#     typedef struct CacheBlock
#     {
#         char _blk_flag[FLAG_SIZE];  // 块标识符，用于验证文件完整性
#         uint32_t _size;  // 当前缓存项数量
#         uint32_t _capacity;  // 缓存块容量（最大缓存项数量）
#         uint32_t _date;  // 缓存日期，用于判断是否需要重置
#         CacheItem _items[0];  // 缓存项数组，零长度数组实现动态大小
#     } CacheBlock;  // 缓存块类型别名
#
#     typedef struct _CacheItem
# 	{
# 		char	_key[64] = { 0 };  // 缓存项键，最大64字符
# 		char	_val[64] = { 0 };  // 缓存项值，最大64字符
# 	} CacheItem;  // 缓存项类型别名
#     ```
#   - ***`BoostMFPtr _file`***：内存映射文件智能指针
#     ```cpp
#     typedef std::shared_ptr<BoostMappingFile> BoostMFPtr;
#     ```
# - ***`SpinMutex _lock`***：自旋锁，保证线程安全
# - ***`wt_hashmap<std::string, uint32_t> _indice`***：哈希表索引，键到索引位置的映射

# %% [markdown]
# ```mermaid
# graph TD
#     subgraph instance["WtKVCache 实例"]
#         direction LR
#         A["**API接口**<br>put(key, val)<br>get(key)<br>has(key)"] --> CoreLogic{"**核心逻辑**"};
#
#         subgraph CoreLogicContainer[" "]
#             direction TB
#             C["**内存哈希索引**<br>wt_hashmap&lt;string, uint32_t&gt _indice;<br><br><b>作用:</b> O(1)复杂度的 Key -> Index 快速查找"]
#             D["**线程安全控制**<br>SpinMutex _lock<br><br><b>作用:</b> 仅在写入和扩容时加锁"]
#         end
#     end
#
#     subgraph mmap["内存映射区 (由OS管理)"]
#         E["**内存映射文件视图 (CacheBlockPair _cache)**"]
#     end
#
#     subgraph disk["物理磁盘"]
#         F["**持久化缓存文件**<br>例如: cache.dat"]
#     end
#
#     style A fill:#cde4ff,stroke:#333,stroke-width:2px
#     style C fill:#e6ffcd,stroke:#333,stroke-width:2px
#     style D fill:#ffe6cd,stroke:#333,stroke-width:2px
#     style E fill:#f9f,stroke:#333,stroke-width:2px
#     style F fill:#bbf,stroke:#333,stroke-width:2px
#
#     %% 定义节点之间的连接
#     CoreLogic -- "读/写指定索引位置" --> E;
#     E     <== "<b>内存 <-> 磁盘<br>由OS自动同步</b>" ==> F;
#     C     -- "获取数据索引" --> CoreLogic;
#     D     -- "保护写操作" --> CoreLogic;
# ```

# %% [markdown]
# 包含方法：
# - **初始化缓存**：`bool init(const char* filename, uint32_t uDate, CacheLogger logger = nullptr)`
# - **调整缓存大小**：`bool resize(uint32_t newCap, CacheLogger logger = nullptr)`
# - **清空缓存**：`inline void clear()`
# - **获取缓存容量**：`inline uint32_t capacity() const`
# - **获取缓存项数量**：`inline uint32_t size() const`
# - **检查键是否存在**：`inline bool has(const char* key) const`
# - **获取缓存值**：`inline const char*	get(const char* key) const`
# - **设置缓存值**：`void	put(const char* key, const char*val, std::size_t len = 0, CacheLogger logger = nullptr)`
